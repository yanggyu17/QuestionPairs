# %%
import numpy as np
from sklearn.cross_validation import train_test_split
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## Reading data

# %%
with open('./data/kin_data', 'r') as f:
    data = f.readlines()
with open('./data/kin_label', 'r') as f:
    label = f.readlines()

# %% [markdown]
# ## Data split

# %%
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size = 0.3)

# %%
x_train[0:100]
# Out:
# ["'낙동강 오리알'이란 말이있는데.......\t낙동강 둑에..\n",
#  "키우는 바다새우, 씨몽키란 무엇인가요?\t'씨몽키'라는건 뭔가요?\n",
#  '국가대표 유니폼 이름 마킹...\t국가대표 유니폼 이름박을려고하는데\n',
#  '스마일마스크증후군\t스마일마스크증후군 내공 100\n',
#  '커튼 길이에 따라 세금을 받는다?\t건물 살때 세금부분.\n',
#  '한식 상차림의 종류와 방법에 대한 소개/내공있음\t5첩상차림에 대해서 설명해주세요~\n',
#  '비가 올 때 소리가 더 크게 들리는 이유...!\t비가 온 후에 밤이 더 밝은 이유\n',
#  'ECC 와 EU의 차이점\tEU와 US의 차이\n',
#  '코코넛오일 오가닉버진과 엑스트라버진의 차이\t엑스트라버진 코코넛오일을\n',
#  '마이너스통장에 대해 자세히 알려주세요\t마이너스 통장에 대해서 알려주세요\n',
#  '상토와 부엽토와 배양토의 차이점은 무엇인가요?\t동양란과 서양란의 차이점은?\n',
#  '비행기의 공중급유 어떻게 이루어지는건가요???\t비행기는 어떻게 착륙?\n',
#  '비행기는 왜 구름속에서 흔들리나요\t비행기는 왜 높이 날까요?\n',
#  '숟가락에 오목한곳을 보면 왜 사람이 뒤집혀서 보일까?\t숟가락을 왜 뒤집어서 놓으면 안될까-_-;a\n',
#  '전자상거래관리사 응시자격문의\t전자상거래관리사 취득자격은?\n',
#  '영화 황진이에서 기생들의 죽음을 무슨 상이라고 하나요?\t"동이""에 인현왕후가 죽고 중전은 누가 되나요?\n',
#  '온도계 안에 있는 빨간 알코올이 끊어지면 어떻게?\t알코올온도계에 빨간줄이 끝에까지 올라와 있어요\n',
#  '블로그에 올리는 팬픽도 저작권법에 위반되나요?\t저작권침해가 논란이 되고 있잖아요..?\n',
#  '스크린 쿼터제?\t스크린 쿼터제에 대해\n',
#  '초밥의 유래 간단하게\t초밥의 유래는?\n',
#  'PPA가 뭔가요???\t당이뭔가요???\n',
#  '칼에 구멍이 뚫려있는 이유는?\t식칼에 구멍이 뚫려 있는 이유는?\n',
#  '고급 레스토랑에서 지켜야할 에티켓\t레스토랑의 좋은 점\n',
#  '집에서만들수있는 간단 강아지 간식\t강아지 간식을 만들려고 하는데요\n',
#  '10짜리 동전을 소주에,,담궈두면,, 냉장고 냄새가,,움써진다던뎅,,,,\t냉장고에 10원짜리를 놓으면 냉장고 냄새가 없어진다?\n',
#  '피라미드가 가장 많은 나라는 멕시코?\t세계에서 가장 높고 무거운 빌딩.\n',
#  "어떤사람들 리바이스가 미국에서 망햇다 하시는데 !!!\t미국에서는 리바이스(Levi's)가 거지들이 입는 옷인가요?-_-?\n",
#  '수학공식특허\t수학공식도 특허가 있나요??(내공100)\n',
#  '반응성 애착증세가 무엇인가요??\t소화계 관련질병\n',
#  '도넛 가운데에 구멍이생긴이유\t도넛의 가운데에 왜 구멍이 있을까??????\n',
#  '경매(대위변제)에 대한 질문입니다.\t부동산경매 용어중에서 대위변제에 대해 알고 싶습니다.\n',
#  '홍차와 허브차의 차이\t녹차와 홍차의 차이점 알려 주세요.\n',
#  "'문자도'가 무엇이죠??\t문자가 무엇을 의미할까요?\n",
#  '국회의 대통령 탄핵은?\t만약 진짜로 대통령을 탄핵했다면 그다음은.?\n',
#  '한국화에 난초와 귀뚜라미가 함께 그려지는 이유가 뭐죠?\t문지방이 있는 이유가 무엇입니까?\n',
#  '간지럼을 태우면 왜 웃는 거죠???\t간지럼을 태우면 웃음이 나오는 이유는?\n',
#  'ogg가 mp3보다 음질이 더 좋은 이유는 무엇인가요?\twave가 음질이 좋나요? ogg가 음질이 좋나요?.\n',
#  '담배피면 체중이 감소하고 늘어나지않나요?\t담배를 끈으면 무조건 체중이 증가하나요???????????????????\n',
#  '매의 시력은..?\t사람의 시력은?\n',
#  '바나나가 검게변하는이유좀 정확하게 알려주세요\t바나나가 까맣게 되는 이유-_-?\n',
#  '아이스와인이 뭐해요?\t아이스와인 잔 ??\n',
#  '만화책 보관하는 법\t만화책 보관 방법이요!\n',
#  '손톱,발톱관리에대해...\t손톱이랑 발톱 관리할껀데요ㅜ\n',
#  '어쿠스틱기타\t어쿠스틱 기타[!!!!!!!!!!!!!]\n',
#  '보통 한복과 개량된 한복의 차이\t개량한복의 장점\n',
#  '4월이 과학의달인 이유\t과학의날이 4월 21일아닌가요?\n',
#  '플래시몹이 먼가요?\t플래시가 뭐하는 거예요???\n',
#  '물고기에도 혀가 있나요?\t물고기에게 혀가 있나요?\n',
#  '비행기창문의 구조는 어떻게 생긴거죠?\t비행기의 창문\n',
#  '우울증에좋은음식은 어떤것\t우울증에 좋은 음식이 뭐가있나요\n',
#  '영화필름현상과정\t영화필름을 일반사진 처럼 현상가능한가요?\n',
#  '2006년 월드컵 경기에 벤치 멤버는 몇 명인가요? 감독 코치 등등 해서..\t이번 2006독일월드컵때도 2002년때 처럼 열광적인 길거리응원할 확률은??\n',
#  '크리스마스 트리는 누가 언제 어떻게 만들었을까요?\t크리스마스 트리는 언제부터 만들었나요?\n',
#  '길거리에서 애국가를 큰소리로 진지하게 부르면 경찰이 잡아가나여?\t남자들이 애국가를 부르는 이유가 머에여??친구들한테 물어보면 계속 웃기만하구 안 알려주더라구요ㅠㅠ알려주세여~\n',
#  '회계사는...\t회계사라는게\n',
#  '알약은 왜 흰색이 많을까?\t알약의 색은 왜 대게 희죠?\n',
#  '떫은감꼭지에 소주를 부으면 홍시가 되는 이유\t소주중에서 참이슬을 많이 마시는 이유?ㅡㅡ;\n',
#  '자동차 튜닝에 대해 알려주세요\t자동차 튜닝에 대해서 알고 싶어요\n',
#  '리바이스 청바지는 따른 바지와 차이점이??\t왜 리바이스청바지는 종류가 다양하지 않을까여?\n',
#  '이슬람교도들이 돼지고기를 먹지 않는 이유\t이슬람에서는 돼지를 왜? 숭배하나요?\n',
#  '법원에서 진짜 존경하는 재판장님 이렇게부르나요?\t법원에서 이름바꾸는데 얼마나 하나요?\n',
#  '산에 있는 나무에 등을 마사지 하는 분이 많은데 의학적으로 좋은건가요?\t손이 차가울때 먹는 약재~~\n',
#  '캡슐약에관해서\t캡슐약 질문입니다\n',
#  '거미는 왜 거미줄에 안 걸리나요?\t거미는 왜 거미줄에 안걸리는지\n',
#  '딤섬이 뭔가요??\t폭립이뭔가요?\n',
#  '[주식시세표] 주식시세표에 나온 용어와 일반적인 주식관련 용어 질문\t주식에 대하여 , ( 그래프보는법 , 용어 등 )\n',
#  '일반인도 고해성사가 가능한가요?\t무교라도 고해성사를 받을 수 있나요??\n',
#  '생활상식많이알켜주세요\t유용한 생활지식 갈켜주세요..?\n',
#  '쥐나 말은 토를 못한다??????\t의리가 밥을주지않는다\n',
#  "외국영화를볼때마다'번역 이미도'라고 있는데요 이미도님에 대해 궁금해요\t우리나라영화는 외국영화에 비해 문제가 많은 거 같아요\n",
#  '핏줄은 왜 파란색인가요?\t핏줄은 왜 파란 색일까요?\n',
#  '새롭게 탄생한 2006 월드컵 응원가\t월드컵응원가\n',
#  '사랑을 식게 만드는 납화살?\t쩝... 사랑...\n',
#  '냉장고 안에 십원짜리 동전을 올려놓던데..\t10짜리 동전을 소주에,,담궈두면,, 냉장고 냄새가,,움써진다던뎅,,,,\n',
#  '우리나라의 첫 해외파병은요?\t우리나라의 국군파병할때\n',
#  '눈물샘에서 눈물이 생겨나는 과정\t눈물샘이 없다면?\n',
#  '불법체류자가 로또복권 1등 당첨되면?\t로또 복권을 불법체류자가 당첨됐다면??\n',
#  '물을 마시면 몇분만에 오줌이 되어 나올까?\t물을 마시면 오줌이 나올까요?\n',
#  '항공기 탑승할때 기내에서 허용되는 무게?\t제스트항공 국내선 기내에 가지고 탈 수 있는 무게와 크기\n',
#  '최고의 반전영화는?\t님들이 보신 최고의 영화는?\n',
#  "도금 하는것을 우리는 속어로 '멕기 입힌다'?\t나야말로, 언제나 반갑게 맞이해주어서 고맙다.\n",
#  '샤갈의 그림과 마을?\t샤갈이 그린 그림의 구도\n',
#  '일본 사무라이들이 깎는 머리를 뭐라고 부르나요?\t일본에서는 반삭이나 스포츠머리를 머라고 해요?\n',
#  '유니코드가 뭐예요?\t유니코드란 무엇입니까?\n',
#  '공무원급수 에따른 직책.\t공무원의 급수\n',
#  '꿈을 사고 파는게 진짤까여~~?\t꿈을 사고 팔수 있나요?\n',
#  '꿈을 자주 꾸면 피곤한건가요?\t꿈을꾸면 왜 꿈인지 모르죠\n',
#  '중국의 사대악녀에 대해 알고 싶어여..\t중국3대여걸에 대하여..알려주세여..,.\n',
#  '세상에서 가장비싼보석\t이세상에서 가장 비싼 보석은?\n',
#  '녹차 세수는 어떻게 하는거에요..\t녹차세수 어떻게????\n',
#  '화장지의 시초는 누구인가요?\t냉장고를만든사람은누구에요?\n',
#  '기차는 왜 좌측통행인가요?\t기차는 철로가 왜 한개만 놓여져 있나요?\n',
#  '대부분의 갓이 검정색인 이유는...무엇인지.,..ㅎㅎ\t때 색깔이 검은색인 이유는 뭔가요?\n',
#  '수입통관하는데 굳이 무역협회 고유번호 필요한가요?\t꼭 무역협회에 가입해야 하나요? 수입은 한달에 1~2번 정도인데...\n',
#  '제과와 삼강의 차이\t롯데와 롯데삼강의 차이가 뭐죠(아이스크림 회사)\n',
#  '달에 묻힌사람이 있다던데..;;;;;\t요즘에도 그런 사람들이 있는지...\n',
#  '바텐더 자격증이 조주기능사인가요??\t바텐더 하려면 조주기능사 자격증있으면 되나여~?\n',
#  '기내좌석에는 왜 I(영문:아이) 자리가 없나요?\t비행기좌석이좁은이유\n',
#  '콜라를 마시면 정말 이가 녹나요?\t콜라를 많이 마시면 이가 녹나요?\n',
#  '세계 여러나라에서 새해에 먹는 음식들../새해에 하는여러행사..\t세계 여러 나라의 명절, 축제모습\n']

# %%
for i in range(100):
    print(x_train[i], y_train[i])
# Out:
# '낙동강 오리알'이란 말이있는데.......	낙동강 둑에..
#  0
#
# 키우는 바다새우, 씨몽키란 무엇인가요?	'씨몽키'라는건 뭔가요?
#  1
#
# 국가대표 유니폼 이름 마킹...	국가대표 유니폼 이름박을려고하는데
#  0
#
# 스마일마스크증후군	스마일마스크증후군 내공 100
#  1
#
# 커튼 길이에 따라 세금을 받는다?	건물 살때 세금부분.
#  0
#
# 한식 상차림의 종류와 방법에 대한 소개/내공있음	5첩상차림에 대해서 설명해주세요~
#  0
#
# 비가 올 때 소리가 더 크게 들리는 이유...!	비가 온 후에 밤이 더 밝은 이유
#  0
#
# ECC 와 EU의 차이점	EU와 US의 차이
#  0
#
# 코코넛오일 오가닉버진과 엑스트라버진의 차이	엑스트라버진 코코넛오일을
#  0
#
# 마이너스통장에 대해 자세히 알려주세요	마이너스 통장에 대해서 알려주세요
#  1
#
# 상토와 부엽토와 배양토의 차이점은 무엇인가요?	동양란과 서양란의 차이점은?
#  0
#
# 비행기의 공중급유 어떻게 이루어지는건가요???	비행기는 어떻게 착륙?
#  0
#
# 비행기는 왜 구름속에서 흔들리나요	비행기는 왜 높이 날까요?
#  0
#
# 숟가락에 오목한곳을 보면 왜 사람이 뒤집혀서 보일까?	숟가락을 왜 뒤집어서 놓으면 안될까-_-;a
#  0
#
# 전자상거래관리사 응시자격문의	전자상거래관리사 취득자격은?
#  1
#
# 영화 황진이에서 기생들의 죽음을 무슨 상이라고 하나요?	"동이""에 인현왕후가 죽고 중전은 누가 되나요?
#  0
#
# 온도계 안에 있는 빨간 알코올이 끊어지면 어떻게?	알코올온도계에 빨간줄이 끝에까지 올라와 있어요
#  0
#
# 블로그에 올리는 팬픽도 저작권법에 위반되나요?	저작권침해가 논란이 되고 있잖아요..?
#  0
#
# 스크린 쿼터제?	스크린 쿼터제에 대해
#  1
#
# 초밥의 유래 간단하게	초밥의 유래는?
#  1
#
# PPA가 뭔가요???	당이뭔가요???
#  0
#
# 칼에 구멍이 뚫려있는 이유는?	식칼에 구멍이 뚫려 있는 이유는?
#  1
#
# 고급 레스토랑에서 지켜야할 에티켓	레스토랑의 좋은 점
#  0
#
# 집에서만들수있는 간단 강아지 간식	강아지 간식을 만들려고 하는데요
#  1
#
# 10짜리 동전을 소주에,,담궈두면,, 냉장고 냄새가,,움써진다던뎅,,,,	냉장고에 10원짜리를 놓으면 냉장고 냄새가 없어진다?
#  1
#
# 피라미드가 가장 많은 나라는 멕시코?	세계에서 가장 높고 무거운 빌딩.
#  0
#
# 어떤사람들 리바이스가 미국에서 망햇다 하시는데 !!!	미국에서는 리바이스(Levi's)가 거지들이 입는 옷인가요?-_-?
#  1
#
# 수학공식특허	수학공식도 특허가 있나요??(내공100)
#  1
#
# 반응성 애착증세가 무엇인가요??	소화계 관련질병
#  0
#
# 도넛 가운데에 구멍이생긴이유	도넛의 가운데에 왜 구멍이 있을까??????
#  1
#
# 경매(대위변제)에 대한 질문입니다.	부동산경매 용어중에서 대위변제에 대해 알고 싶습니다.
#  1
#
# 홍차와 허브차의 차이	녹차와 홍차의 차이점 알려 주세요.
#  0
#
# '문자도'가 무엇이죠??	문자가 무엇을 의미할까요?
#  0
#
# 국회의 대통령 탄핵은?	만약 진짜로 대통령을 탄핵했다면 그다음은.?
#  1
#
# 한국화에 난초와 귀뚜라미가 함께 그려지는 이유가 뭐죠?	문지방이 있는 이유가 무엇입니까?
#  0
#
# 간지럼을 태우면 왜 웃는 거죠???	간지럼을 태우면 웃음이 나오는 이유는?
#  1
#
# ogg가 mp3보다 음질이 더 좋은 이유는 무엇인가요?	wave가 음질이 좋나요? ogg가 음질이 좋나요?.
#  0
#
# 담배피면 체중이 감소하고 늘어나지않나요?	담배를 끈으면 무조건 체중이 증가하나요???????????????????
#  0
#
# 매의 시력은..?	사람의 시력은?
#  0
#
# 바나나가 검게변하는이유좀 정확하게 알려주세요	바나나가 까맣게 되는 이유-_-?
#  1
#
# 아이스와인이 뭐해요?	아이스와인 잔 ??
#  1
#
# 만화책 보관하는 법	만화책 보관 방법이요!
#  1
#
# 손톱,발톱관리에대해...	손톱이랑 발톱 관리할껀데요ㅜ
#  1
#
# 어쿠스틱기타	어쿠스틱 기타[!!!!!!!!!!!!!]
#  1
#
# 보통 한복과 개량된 한복의 차이	개량한복의 장점
#  0
#
# 4월이 과학의달인 이유	과학의날이 4월 21일아닌가요?
#  0
#
# 플래시몹이 먼가요?	플래시가 뭐하는 거예요???
#  0
#
# 물고기에도 혀가 있나요?	물고기에게 혀가 있나요?
#  1
#
# 비행기창문의 구조는 어떻게 생긴거죠?	비행기의 창문
#  0
#
# 우울증에좋은음식은 어떤것	우울증에 좋은 음식이 뭐가있나요
#  1
#
# 영화필름현상과정	영화필름을 일반사진 처럼 현상가능한가요?
#  0
#
# 2006년 월드컵 경기에 벤치 멤버는 몇 명인가요? 감독 코치 등등 해서..	이번 2006독일월드컵때도 2002년때 처럼 열광적인 길거리응원할 확률은??
#  0
#
# 크리스마스 트리는 누가 언제 어떻게 만들었을까요?	크리스마스 트리는 언제부터 만들었나요?
#  1
#
# 길거리에서 애국가를 큰소리로 진지하게 부르면 경찰이 잡아가나여?	남자들이 애국가를 부르는 이유가 머에여??친구들한테 물어보면 계속 웃기만하구 안 알려주더라구요ㅠㅠ알려주세여~
#  0
#
# 회계사는...	회계사라는게
#  1
#
# 알약은 왜 흰색이 많을까?	알약의 색은 왜 대게 희죠?
#  1
#
# 떫은감꼭지에 소주를 부으면 홍시가 되는 이유	소주중에서 참이슬을 많이 마시는 이유?ㅡㅡ;
#  0
#
# 자동차 튜닝에 대해 알려주세요	자동차 튜닝에 대해서 알고 싶어요
#  1
#
# 리바이스 청바지는 따른 바지와 차이점이??	왜 리바이스청바지는 종류가 다양하지 않을까여?
#  0
#
# 이슬람교도들이 돼지고기를 먹지 않는 이유	이슬람에서는 돼지를 왜? 숭배하나요?
#  1
#
# 법원에서 진짜 존경하는 재판장님 이렇게부르나요?	법원에서 이름바꾸는데 얼마나 하나요?
#  0
#
# 산에 있는 나무에 등을 마사지 하는 분이 많은데 의학적으로 좋은건가요?	손이 차가울때 먹는 약재~~
#  0
#
# 캡슐약에관해서	캡슐약 질문입니다
#  1
#
# 거미는 왜 거미줄에 안 걸리나요?	거미는 왜 거미줄에 안걸리는지
#  1
#
# 딤섬이 뭔가요??	폭립이뭔가요?
#  0
#
# [주식시세표] 주식시세표에 나온 용어와 일반적인 주식관련 용어 질문	주식에 대하여 , ( 그래프보는법 , 용어 등 )
#  0
#
# 일반인도 고해성사가 가능한가요?	무교라도 고해성사를 받을 수 있나요??
#  1
#
# 생활상식많이알켜주세요	유용한 생활지식 갈켜주세요..?
#  1
#
# 쥐나 말은 토를 못한다??????	의리가 밥을주지않는다
#  0
#
# 외국영화를볼때마다'번역 이미도'라고 있는데요 이미도님에 대해 궁금해요	우리나라영화는 외국영화에 비해 문제가 많은 거 같아요
#  0
#
# 핏줄은 왜 파란색인가요?	핏줄은 왜 파란 색일까요?
#  1
#
# 새롭게 탄생한 2006 월드컵 응원가	월드컵응원가
#  0
#
# 사랑을 식게 만드는 납화살?	쩝... 사랑...
#  0
#
# 냉장고 안에 십원짜리 동전을 올려놓던데..	10짜리 동전을 소주에,,담궈두면,, 냉장고 냄새가,,움써진다던뎅,,,,
#  1
#
# 우리나라의 첫 해외파병은요?	우리나라의 국군파병할때
#  0
#
# 눈물샘에서 눈물이 생겨나는 과정	눈물샘이 없다면?
#  0
#
# 불법체류자가 로또복권 1등 당첨되면?	로또 복권을 불법체류자가 당첨됐다면??
#  1
#
# 물을 마시면 몇분만에 오줌이 되어 나올까?	물을 마시면 오줌이 나올까요?
#  0
#
# 항공기 탑승할때 기내에서 허용되는 무게?	제스트항공 국내선 기내에 가지고 탈 수 있는 무게와 크기
#  1
#
# 최고의 반전영화는?	님들이 보신 최고의 영화는?
#  1
#
# 도금 하는것을 우리는 속어로 '멕기 입힌다'?	나야말로, 언제나 반갑게 맞이해주어서 고맙다.
#  0
#
# 샤갈의 그림과 마을?	샤갈이 그린 그림의 구도
#  0
#
# 일본 사무라이들이 깎는 머리를 뭐라고 부르나요?	일본에서는 반삭이나 스포츠머리를 머라고 해요?
#  0
#
# 유니코드가 뭐예요?	유니코드란 무엇입니까?
#  1
#
# 공무원급수 에따른 직책.	공무원의 급수
#  0
#
# 꿈을 사고 파는게 진짤까여~~?	꿈을 사고 팔수 있나요?
#  1
#
# 꿈을 자주 꾸면 피곤한건가요?	꿈을꾸면 왜 꿈인지 모르죠
#  0
#
# 중국의 사대악녀에 대해 알고 싶어여..	중국3대여걸에 대하여..알려주세여..,.
#  0
#
# 세상에서 가장비싼보석	이세상에서 가장 비싼 보석은?
#  1
#
# 녹차 세수는 어떻게 하는거에요..	녹차세수 어떻게????
#  1
#
# 화장지의 시초는 누구인가요?	냉장고를만든사람은누구에요?
#  0
#
# 기차는 왜 좌측통행인가요?	기차는 철로가 왜 한개만 놓여져 있나요?
#  0
#
# 대부분의 갓이 검정색인 이유는...무엇인지.,..ㅎㅎ	때 색깔이 검은색인 이유는 뭔가요?
#  0
#
# 수입통관하는데 굳이 무역협회 고유번호 필요한가요?	꼭 무역협회에 가입해야 하나요? 수입은 한달에 1~2번 정도인데...
#  1
#
# 제과와 삼강의 차이	롯데와 롯데삼강의 차이가 뭐죠(아이스크림 회사)
#  1
#
# 달에 묻힌사람이 있다던데..;;;;;	요즘에도 그런 사람들이 있는지...
#  0
#
# 바텐더 자격증이 조주기능사인가요??	바텐더 하려면 조주기능사 자격증있으면 되나여~?
#  1
#
# 기내좌석에는 왜 I(영문:아이) 자리가 없나요?	비행기좌석이좁은이유
#  0
#
# 콜라를 마시면 정말 이가 녹나요?	콜라를 많이 마시면 이가 녹나요?
#  1
#
# 세계 여러나라에서 새해에 먹는 음식들../새해에 하는여러행사..	세계 여러 나라의 명절, 축제모습
#  0
